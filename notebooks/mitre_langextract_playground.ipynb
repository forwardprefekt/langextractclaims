# %% [markdown]
# # MITRE LangExtract Mini Flow + Relationship Graph
#
# This notebook runs the self-contained `mitre-langextract-mini` workflow on a fixed seed URL, then visualizes how claims, citations, validation, and MITRE techniques are connected.

# %% [markdown]
# ## 1) Install dependencies

# %%
# %pip install -q langextract requests trafilatura waybackpy pypdf networkx plotly pandas nbformat
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2) Imports and configuration

# %%
import json
import os
import sys
from pathlib import Path

import networkx as nx
import plotly.graph_objects as go

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent

PKG_SRC = ROOT / 'packages' / 'mitre-langextract-mini' / 'src'
if str(PKG_SRC) not in sys.path:
    sys.path.insert(0, str(PKG_SRC))

from mitre_langextract_mini.workflow import run_random_reference_langextract

SEED_URL = 'https://therecord.media/dutch-telecom-giant-announces-data-breach'
USE_LANGEXTRACT = bool(os.getenv('OPENAI_API_KEY'))
TIMEOUT_SECONDS = 45
MAX_WAYBACK_URLS = 8

print(f'Seed URL: {SEED_URL}')
print(f'USE_LANGEXTRACT={USE_LANGEXTRACT} (set OPENAI_API_KEY to enable model extraction)')
print(f'Package source path: {PKG_SRC}')
# Out:
# Seed URL: https://therecord.media/dutch-telecom-giant-announces-data-breach
# USE_LANGEXTRACT=True (set OPENAI_API_KEY to enable model extraction)
# Package source path: /home/gangsta/hustle/mybot/packages/mitre-langextract-mini/src

# %% [markdown]
# ## 3) Run extraction + validation flow

# %%
result = run_random_reference_langextract(
    reference_url=SEED_URL,
    use_langextract=USE_LANGEXTRACT,
    prefer_wayback=True,
    max_wayback_urls=MAX_WAYBACK_URLS,
    timeout=TIMEOUT_SECONDS,
)

status = result.get('status', {})
reference = result.get('reference', {})
summary = {
    'results_source': status.get('results_source'),
    'claims_count': status.get('claims_count'),
    'falsifiable_claims_count': status.get('falsifiable_claims_count'),
    'mitre_claims_count': status.get('mitre_claims_count'),
    'mitre_linkages_count': status.get('mitre_linkages_count'),
    'download_source': reference.get('download_source'),
    'resolved_url': reference.get('resolved_url'),
}
print(json.dumps(summary, indent=2))
# Out:
# {
#   "results_source": "langextract",
#   "claims_count": 21,
#   "falsifiable_claims_count": 20,
#   "mitre_claims_count": 1,
#   "mitre_linkages_count": 2,
#   "download_source": "wayback",
#   "resolved_url": "https://web.archive.org/web/20260213141303/https://therecord.media/dutch-telecom-giant-announces-data-breach"
# }

# %% [markdown]
# ## 4) Inspect linkage-level validation explanations

# %%
linkages = result.get('mitre_linkages') or []
print(f'Total MITRE linkages: {len(linkages)}')

for idx, linkage in enumerate(linkages[:5], start=1):
    print(f'\n[{idx}] {linkage.get("mitre_id")} {linkage.get("technique_name")}')
    print(f'Claim: {linkage.get("claim_text")}')
    validation = linkage.get('validation') or {}
    print(f'Validation: {validation.get("verdict")} score={validation.get("score")}')
    print(f'Validation explanation: {validation.get("explanation")}')
    for cidx, citation in enumerate((linkage.get('citations') or [])[:2], start=1):
        print(f'  Citation {cidx}: offsets={citation.get("start")}:{citation.get("end")}')
        print(f'    relation_to_mitre={citation.get("relation_to_mitre")}')
        print(f'    validation_explanation={citation.get("validation_explanation")}')
        print(f'    quote={citation.get("quote")!r}')
# Out:
# Total MITRE linkages: 2
#
# [1] T1566 Phishing
# Claim: Some may send phishing emails made to look like Odido communications.
# Validation: supported score=0.75
# Validation explanation: Citation includes the technique name for Phishing (T1566), grounding the MITRE linkage in source text.
#   Citation 1: offsets=1343:1412
#     relation_to_mitre=technique_name_match
#     validation_explanation=Citation includes the technique name for Phishing (T1566), grounding the MITRE linkage in source text.
#     quote='Some may send phishing emails made to look like Odido communications.'
#   Citation 2: offsets=1357:1365
#     relation_to_mitre=technique_name_match
#     validation_explanation=Citation includes the technique name for Phishing (T1566), grounding the MITRE linkage in source text.
#     quote='phishing'
#
# [2] T1589.002 Email Addresses
# Claim: In a statement about the incident, Odido CEO Søren Abildgaard said names, bank account numbers, addresses, mobile numbers, email addresses, account numbers and IDs – ranging from passports to driver's license numbers – were stolen by the hackers.
# Validation: supported score=0.98
# Validation explanation: Citation includes the technique name for Email Addresses (T1589.002), grounding the MITRE linkage in source text.
#   Citation 1: offsets=281:527
#     relation_to_mitre=technique_name_match
#     validation_explanation=Citation includes the technique name for Email Addresses (T1589.002), grounding the MITRE linkage in source text.
#     quote="In a statement about the incident, Odido CEO Søren Abildgaard said names, bank account numbers, addresses, mobile numbers, email addresses, account numbers and IDs – ranging from passports to driver's license numbers – were stolen by the hackers."
#   Citation 2: offsets=404:419
#     relation_to_mitre=technique_name_match
#     validation_explanation=Citation includes the technique name for Email Addresses (T1589.002), grounding the MITRE linkage in source text.
#     quote='email addresses'

# %% [markdown]
# ## 5) Tabular view for non-MITRE claims

# %%
try:
    import pandas as pd
except ImportError as exc:
    raise RuntimeError(
        "pandas is required for tabular output in this notebook. "
        "Install in this kernel with: %pip install pandas"
    ) from exc

from IPython.display import display


def _clip(value: str, limit: int = 120) -> str:
    text = ' '.join(str(value or '').split())
    if len(text) <= limit:
        return text
    return text[: max(0, limit - 3)] + '...'


claim_assessments = result.get('claim_assessments') or []
claim_references = result.get('claim_associations') or []

if not claim_assessments:
    print('No claim_assessments found in result payload.')
else:
    non_mitre_claims = [
        claim
        for claim in claim_assessments
        if not str(claim.get('mitre_id') or '').strip()
        and not str(claim.get('technique_name') or '').strip()
    ]

    if not non_mitre_claims:
        print('No non-MITRE claims found.')
    else:
        summary_rows = []
        for claim in non_mitre_claims:
            summary_rows.append(
                {
                    'claim_id': claim.get('claim_id'),
                    'claim_state': claim.get('state'),
                    'confidence': claim.get('confidence'),
                    'validation_method': claim.get('validation_method'),
                    'claim_scope': claim.get('claim_scope'),
                    'source': claim.get('source'),
                    'references_total': (
                        int(claim.get('support_reference_count') or 0)
                        + int(claim.get('contradict_reference_count') or 0)
                        + int(claim.get('neutral_reference_count') or 0)
                    ),
                    'support_refs': int(claim.get('support_reference_count') or 0),
                    'contradict_refs': int(claim.get('contradict_reference_count') or 0),
                    'neutral_refs': int(claim.get('neutral_reference_count') or 0),
                    'claim_text': _clip(claim.get('claim_text'), 180),
                    'assessment_reason': _clip(claim.get('reason'), 180),
                }
            )

        summary_df = pd.DataFrame(summary_rows)
        summary_df = summary_df.sort_values(
            by=['claim_state', 'confidence', 'references_total', 'claim_id'],
            ascending=[True, False, False, True],
            na_position='last',
        ).reset_index(drop=True)

        print(f'Non-MITRE claims: {len(summary_df)}')
        display(summary_df)

        non_mitre_ids = set(summary_df['claim_id'].astype(str).tolist())
        refs = [
            ref
            for ref in claim_references
            if str(ref.get('claim_id') or '') in non_mitre_ids
        ]

        if refs:
            claim_state_by_id = {
                str(row.get('claim_id') or ''): row.get('claim_state')
                for row in summary_rows
            }
            refs_rows = []
            for ref in refs:
                claim_id = str(ref.get('claim_id') or '')
                refs_rows.append(
                    {
                        'claim_id': claim_id,
                        'claim_state': claim_state_by_id.get(claim_id),
                        'stance': ref.get('stance'),
                        'stance_source': ref.get('stance_source'),
                        'citation_id': ref.get('citation_id'),
                        'method': ref.get('method'),
                        'relation_to_mitre': ref.get('relation_to_mitre'),
                        'start': ref.get('start'),
                        'end': ref.get('end'),
                        'quote': _clip(ref.get('quote'), 180),
                        'context': _clip(ref.get('context'), 220),
                        'nli_label': ref.get('nli_label'),
                        'nli_confidence': ref.get('nli_confidence'),
                        'nli_reason': _clip(ref.get('nli_reason'), 140),
                        'reference_url': ref.get('reference_url'),
                    }
                )

            refs_df = pd.DataFrame(refs_rows)
            refs_df = refs_df.sort_values(
                by=['claim_id', 'stance', 'start', 'citation_id'],
                ascending=[True, True, True, True],
                na_position='last',
            ).reset_index(drop=True)

            print(f'Non-MITRE claim references/citations: {len(refs_df)}')
            display(refs_df)
        else:
            print('No reference/citation rows for non-MITRE claims.')
# Out:
# Non-MITRE claims: 18
#               claim_id claim_state  confidence validation_method  \
# 0   claim_7deab3579c4c     partial              0.65  self_referential
# 1   claim_7f80aede0027     partial              0.65  self_referential
# 2   claim_a070ef3cd59b     partial              0.65  self_referential
# 3   claim_124e9174b84d     partial              0.58  self_referential
# 4   claim_3035f4d22b62     partial              0.58  self_referential
# 5   claim_7e2e61c3ce97     partial              0.58  self_referential
# 6   claim_86597f12534f     partial              0.58  self_referential
# 7   claim_cdb5f61c567e     partial              0.58  self_referential
# 8   claim_cf1c13939d3b     partial              0.58  self_referential
# 9   claim_1c53981c8b8a   supported              0.88  self_referential
# 10  claim_399b935a13ac   supported              0.88  self_referential
# 11  claim_3a25a33f834b   supported              0.88  self_referential
# 12  claim_4d21f2fba53a   supported              0.88  self_referential
# 13  claim_4eb4ae824013   supported              0.88  self_referential
# 14  claim_6490d9989e48   supported              0.88  self_referential
# 15  claim_8d2c12f4823d   supported              0.88  self_referential
# 16  claim_98e86635224a   supported              0.88  self_referential
# 17  claim_ddb48b9d4ac4   supported              0.88  self_referential
#
#       claim_scope                        source  references_total  \
# 0   cybersecurity  langextract_claim_first_pass                 1
# 1         general  langextract_claim_first_pass                 1
# 2         general  langextract_claim_first_pass                 1
# 3   cybersecurity  langextract_claim_first_pass                 1
# 4   cybersecurity  langextract_claim_first_pass                 1
# 5   cybersecurity  langextract_claim_first_pass                 1
# 6   cybersecurity  langextract_claim_first_pass                 1
# 7   cybersecurity  langextract_claim_first_pass                 1
# 8   cybersecurity  langextract_claim_first_pass                 1
# 9   cybersecurity  falsifiable_claim_extraction                 1
# 10        general  falsifiable_claim_extraction                 1
# 11        general  falsifiable_claim_extraction                 1
# 12        general  falsifiable_claim_extraction                 1
# 13  cybersecurity  falsifiable_claim_extraction                 1
# 14  cybersecurity  falsifiable_claim_extraction                 1
# 15        general  falsifiable_claim_extraction                 1
# 16  cybersecurity  falsifiable_claim_extraction                 1
# 17  cybersecurity  falsifiable_claim_extraction                 1
#
#     support_refs  contradict_refs  neutral_refs  \
# 0                 1                   0             0
# 1                 1                   0             0
# 2                 1                   0             0
# 3                 1                   0             0
# 4                 1                   0             0
# 5                 1                   0             0
# 6                 1                   0             0
# 7                 1                   0             0
# 8                 1                   0             0
# 9                 1                   0             0
# 10                1                   0             0
# 11                1                   0             0
# 12                1                   0             0
# 13                1                   0             0
# 14                1                   0             0
# 15                1                   0             0
# 16                1                   0             0
# 17                1                   0             0
#
#                                            claim_text  \
# 0   They warned victims that hackers could contact...
# 1          6.2 million people had information stolen.
# 2   Customers will be contacted directly by Odido ...
# 3   The cybercriminals downloaded customer informa...
# 4   South Korea’s major mobile carrier, SK Telecom...
# 5   Cyberattacks on large national telecoms have r...
# 6   Investigators traced the attack back to a comp...
# 7   No cybercriminals have come forward to claim t...
# 8   The breach exposed the personal data of about ...
# 9   Abildgaard said the incident took place on Feb...
# 10  Odido has about 7 million customers and has ch...
# 11  Jonathan Greig is a Breaking News Reporter at ...
# 12  The company Odido, told a local news outlet th...
# 13  Dutch mobile phone giant Odido announces data ...
# 14  Last month, French regulators fined a French t...
# 15  Jonathan has worked across the globe as a jour...
# 16  The company’s operations have not been impacte...
# 17  The statement includes several scenarios outli...
#
#                                validation_explanation
# 0   Citation grounds the claim directly in source ...
# 1   Citation grounds the claim directly in source ...
# 2   Citation grounds the claim directly in source ...
# 3   Citation grounds the claim directly in source ...
# 4   Citation grounds the claim directly in source ...
# 5   Citation grounds the claim directly in source ...
# 6   Citation grounds the claim directly in source ...
# 7   Citation grounds the claim directly in source ...
# 8   Citation grounds the claim directly in source ...
# 9   Citation grounds the claim directly in source ...
# 10  Citation grounds the claim directly in source ...
# 11  Citation grounds the claim directly in source ...
# 12  Citation grounds the claim directly in source ...
# 13  Citation grounds the claim directly in source ...
# 14  Citation grounds the claim directly in source ...
# 15  Citation grounds the claim directly in source ...
# 16  Citation grounds the claim directly in source ...
# 17  Citation grounds the claim directly in source ...
# Non-MITRE claim references/citations: 18
#               claim_id claim_state      stance stance_source      citation_id  \
# 0   claim_124e9174b84d     partial  support     heuristic  cite_280dbcb8_1
# 1   claim_1c53981c8b8a   supported  support     heuristic  cite_bd71bbdf_1
# 2   claim_3035f4d22b62     partial  support     heuristic  cite_1138473b_1
# 3   claim_399b935a13ac   supported  support     heuristic  cite_af95c206_1
# 4   claim_3a25a33f834b   supported  support     heuristic  cite_ee6b523b_1
# 5   claim_4d21f2fba53a   supported  support     heuristic  cite_b2fb8531_1
# 6   claim_4eb4ae824013   supported  support     heuristic  cite_bf766e4e_1
# 7   claim_6490d9989e48   supported  support     heuristic  cite_3d9c2c2d_1
# 8   claim_7deab3579c4c     partial  support     heuristic  cite_e762a4b0_1
# 9   claim_7e2e61c3ce97     partial  support     heuristic  cite_08db8ec8_1
# 10  claim_7f80aede0027     partial  support     heuristic  cite_24932f43_1
# 11  claim_86597f12534f     partial  support     heuristic  cite_82c07e6d_1
# 12  claim_8d2c12f4823d   supported  support     heuristic  cite_97d5f662_1
# 13  claim_98e86635224a   supported  support     heuristic  cite_4196ea04_1
# 14  claim_a070ef3cd59b     partial  support     heuristic  cite_3a689ec2_1
# 15  claim_cdb5f61c567e     partial  support     heuristic  cite_3b832f82_1
# 16  claim_cf1c13939d3b     partial  support     heuristic  cite_d4ab4109_1
# 17  claim_ddb48b9d4ac4   supported  support     heuristic  cite_7b2a39a9_1
#
#              method                relation_to_mitre  start   end  \
# 0   extraction_text  self_referential_source_support    773   845
# 1   extraction_span  self_referential_source_support    528   679
# 2   extraction_text  self_referential_source_support   1661  1872
# 3   extraction_span  self_referential_source_support   1413  1572
# 4   extraction_span  self_referential_source_support   2173  2240
# 5   extraction_span  self_referential_source_support    189   280
# 6   extraction_span  self_referential_source_support      0   188
# 7   extraction_span  self_referential_source_support   1941  2172
# 8   extraction_text  self_referential_source_support   1210  1342
# 9   extraction_text  self_referential_source_support   1573  1660
# 10  extraction_text  self_referential_source_support    238   280
# 11  extraction_text  self_referential_source_support    680   772
# 12  extraction_span  self_referential_source_support   2241  2305
# 13  extraction_span  self_referential_source_support    846  1033
# 14  extraction_text  self_referential_source_support   1034  1101
# 15  extraction_text  self_referential_source_support    977  1033
# 16  extraction_text  self_referential_source_support   1873  1940
# 17  extraction_span  self_referential_source_support   1102  1209
#
#                                                 quote  \
# 0   The cybercriminals downloaded customer informa...
# 1   Abildgaard said the incident took place on Feb...
# 2   South Korea’s major mobile carrier, SK Telecom...
# 3   Odido has about 7 million customers and has ch...
# 4   Jonathan Greig is a Breaking News Reporter at ...
# 5   The company Odido, told a local news outlet th...
# 6   Dutch mobile phone giant Odido announces data ...
# 7   Last month, French regulators fined a French t...
# 8   They warned victims that hackers could contact...
# 9   Cyberattacks on large national telecoms have r...
# 10         6.2 million people had information stolen.
# 11  Investigators traced the attack back to a comp...
# 12  Jonathan has worked across the globe as a jour...
# 13  The company’s operations have not been impacte...
# 14  Customers will be contacted directly by Odido ...
# 15  No cybercriminals have come forward to claim t...
# 16  The breach exposed the personal data of about ...
# 17  The statement includes several scenarios outli...
#
#                                               context nli_label  \
# 0   The cybercriminals downloaded customer informa...
# 1   Abildgaard said the incident took place on Feb...
# 2   South Korea’s major mobile carrier, SK Telecom...
# 3   Odido has about 7 million customers and has ch...
# 4   Jonathan Greig is a Breaking News Reporter at ...
# 5   The company Odido, told a local news outlet th...
# 6   Dutch mobile phone giant Odido announces data ...
# 7   Last month, French regulators fined a French t...
# 8   They warned victims that hackers could contact...
# 9   Cyberattacks on large national telecoms have r...
# 10  The company Odido, told a local news outlet th...
# 11  Investigators traced the attack back to a comp...
# 12  Jonathan has worked across the globe as a jour...
# 13  The company’s operations have not been impacte...
# 14  Customers will be contacted directly by Odido ...
# 15  No cybercriminals have come forward to claim t...
# 16  The breach exposed the personal data of about ...
# 17  The statement includes several scenarios outli...
#
#    nli_confidence nli_reason  \
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
#
#                                         reference_url
# 0   https://web.archive.org/web/20260213141303/htt...
# 1   https://web.archive.org/web/20260213141303/htt...
# 2   https://web.archive.org/web/20260213141303/htt...
# 3   https://web.archive.org/web/20260213141303/htt...
# 4   https://web.archive.org/web/20260213141303/htt...
# 5   https://web.archive.org/web/20260213141303/htt...
# 6   https://web.archive.org/web/20260213141303/htt...
# 7   https://web.archive.org/web/20260213141303/htt...
# 8   https://web.archive.org/web/20260213141303/htt...
# 9   https://web.archive.org/web/20260213141303/htt...
# 10  https://web.archive.org/web/20260213141303/htt...
# 11  https://web.archive.org/web/20260213141303/htt...
# 12  https://web.archive.org/web/20260213141303/htt...
# 13  https://web.archive.org/web/20260213141303/htt...
# 14  https://web.archive.org/web/20260213141303/htt...
# 15  https://web.archive.org/web/20260213141303/htt...
# 16  https://web.archive.org/web/20260213141303/htt...
# 17  https://web.archive.org/web/20260213141303/htt...

# %% [markdown]
# ## 6) Build a NetworkX relationship graph

# %%
def _short(text: str, limit: int = 90) -> str:
    value = ' '.join(str(text or '').split())
    if len(value) <= limit:
        return value
    return value[: max(0, limit - 3)] + '...'


def build_relationship_graph(payload: dict, max_claims: int = 50, max_citations_per_linkage: int = 2) -> nx.DiGraph:
    graph = nx.DiGraph()

    reference = payload.get('reference') or {}
    status = payload.get('status') or {}
    reference_url = reference.get('resolved_url') or (reference.get('meta') or {}).get('url') or 'unknown'
    source_name = (reference.get('meta') or {}).get('source_name') or 'reference'

    reference_node = 'reference::document'
    graph.add_node(
        reference_node,
        label=f'Reference: {source_name}',
        node_type='reference',
        hover=f'URL: {reference_url}',
    )

    status_node = 'status::results_source'
    graph.add_node(
        status_node,
        label=f'results_source={status.get("results_source", "unknown")}',
        node_type='status',
        hover=json.dumps(status, indent=2),
    )
    graph.add_edge(reference_node, status_node, relation='processed_as')

    claims = list(payload.get('claims') or [])
    if max_claims:
        claims = claims[:max_claims]

    claim_node_by_id: dict[str, str] = {}
    technique_node_by_key: dict[str, str] = {}

    for index, claim in enumerate(claims, start=1):
        claim_id = str(claim.get('claim_id') or f'claim_{index}')
        claim_node = f'claim::{claim_id}'
        claim_text = str(claim.get('text') or '').strip()
        validation = claim.get('validation') or {}
        verdict = validation.get('verdict')
        score = validation.get('score')
        explanation = validation.get('explanation')

        graph.add_node(
            claim_node,
            label=f'Claim {index}: {_short(claim_text, 80)}',
            node_type='claim',
            hover=(
                f'{claim_text}\n\n'
                f'verdict={verdict} score={score}\n'
                f'validation_explanation={explanation}'
            ),
        )
        graph.add_edge(reference_node, claim_node, relation='contains_claim')
        claim_node_by_id[claim_id] = claim_node

        validation_method = str(claim.get('validation_method') or '').strip()
        if validation_method:
            vm_node = f'validation_method::{validation_method}'
            if vm_node not in graph:
                graph.add_node(
                    vm_node,
                    label=f'Validation method: {validation_method}',
                    node_type='validation_method',
                    hover=validation_method,
                )
            graph.add_edge(claim_node, vm_node, relation='validated_by')

        mitre_id = str(claim.get('mitre_id') or '').strip()
        technique_name = str(claim.get('technique_name') or '').strip()
        if mitre_id or technique_name:
            key = mitre_id or technique_name
            technique_node = f'technique::{key}'
            if technique_node not in graph:
                label = f'{mitre_id} {technique_name}'.strip() or key
                graph.add_node(
                    technique_node,
                    label=f'Technique: {_short(label, 80)}',
                    node_type='technique',
                    hover=label,
                )
            graph.add_edge(claim_node, technique_node, relation='maps_to')
            technique_node_by_key[key] = technique_node

    for linkage in payload.get('mitre_linkages') or []:
        claim_id = str(linkage.get('claim_id') or '').strip()
        claim_node = claim_node_by_id.get(claim_id)
        if not claim_node:
            continue

        mitre_id = str(linkage.get('mitre_id') or '').strip()
        technique_name = str(linkage.get('technique_name') or '').strip()
        technique_key = mitre_id or technique_name
        technique_node = technique_node_by_key.get(technique_key)

        citations = (linkage.get('citations') or [])[:max_citations_per_linkage]
        for idx, citation in enumerate(citations, start=1):
            citation_node = f'citation::{claim_id}::{idx}'
            relation = str(citation.get('relation_to_mitre') or citation.get('method') or 'supports')
            quote = str(citation.get('quote') or '')
            offsets = f'{citation.get("start")}:{citation.get("end")}'
            validation_explanation = str(citation.get('validation_explanation') or '')

            graph.add_node(
                citation_node,
                label=f'Citation {idx}: {_short(quote, 75)}',
                node_type='citation',
                hover=(
                    f'offsets={offsets}\n'
                    f'method={citation.get("method")}\n'
                    f'relation_to_mitre={relation}\n'
                    f'validation_explanation={validation_explanation}'
                ),
            )
            graph.add_edge(claim_node, citation_node, relation='supported_by')
            if technique_node:
                graph.add_edge(citation_node, technique_node, relation=relation)

    return graph

# %% [markdown]
# ## 7) Interactive visualization (Plotly over NetworkX layout)

# %%
def render_interactive_graph(graph: nx.DiGraph, seed: int = 42, width: int = 1300, height: int = 900):
    if graph.number_of_nodes() == 0:
        print('Graph is empty.')
        return None

    k_value = 1.4 / max(1.0, graph.number_of_nodes() ** 0.5)
    pos = nx.spring_layout(graph, seed=seed, k=k_value)

    edge_x, edge_y = [], []
    edge_label_x, edge_label_y, edge_labels = [], [], []
    for src, dst, edge_data in graph.edges(data=True):
        x0, y0 = pos[src]
        x1, y1 = pos[dst]
        edge_x.extend([x0, x1, None])
        edge_y.extend([y0, y1, None])
        edge_label_x.append((x0 + x1) / 2)
        edge_label_y.append((y0 + y1) / 2)
        edge_labels.append(str(edge_data.get('relation') or ''))

    edge_trace = go.Scatter(
        x=edge_x,
        y=edge_y,
        mode='lines',
        line=dict(width=1, color='#9ca3af'),
        hoverinfo='none',
        showlegend=False,
    )

    edge_label_trace = go.Scatter(
        x=edge_label_x,
        y=edge_label_y,
        mode='text',
        text=edge_labels,
        textfont=dict(size=10, color='#6b7280'),
        hoverinfo='none',
        showlegend=False,
    )

    node_style = {
        'reference': {'color': '#2563eb', 'symbol': 'diamond', 'size': 24},
        'status': {'color': '#0891b2', 'symbol': 'square', 'size': 18},
        'claim': {'color': '#059669', 'symbol': 'circle', 'size': 16},
        'technique': {'color': '#dc2626', 'symbol': 'hexagon', 'size': 18},
        'citation': {'color': '#d97706', 'symbol': 'triangle-up', 'size': 14},
        'validation_method': {'color': '#7c3aed', 'symbol': 'square-dot', 'size': 14},
        'other': {'color': '#6b7280', 'symbol': 'circle', 'size': 12},
    }

    traces = [edge_trace, edge_label_trace]
    node_types = sorted({graph.nodes[node].get('node_type', 'other') for node in graph.nodes})

    for node_type in node_types:
        nodes = [node for node in graph.nodes if graph.nodes[node].get('node_type', 'other') == node_type]
        if not nodes:
            continue
        style = node_style.get(node_type, node_style['other'])
        traces.append(
            go.Scatter(
                x=[pos[node][0] for node in nodes],
                y=[pos[node][1] for node in nodes],
                mode='markers+text',
                name=node_type,
                text=[_short(graph.nodes[node].get('label', node), 46) for node in nodes],
                textposition='top center',
                hovertext=[graph.nodes[node].get('hover', '') for node in nodes],
                hoverinfo='text',
                marker=dict(
                    size=style['size'],
                    color=style['color'],
                    symbol=style['symbol'],
                    line=dict(width=1, color='#1f2937'),
                ),
            )
        )

    fig = go.Figure(
        data=traces,
        layout=go.Layout(
            title='Claim/Citation/MITRE relationship graph',
            width=width,
            height=height,
            hovermode='closest',
            showlegend=True,
            margin=dict(l=20, r=20, t=40, b=20),
            xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
            yaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
            dragmode='pan',
        ),
    )
    fig.show()
    return fig

graph = build_relationship_graph(result, max_claims=50, max_citations_per_linkage=2)
print(f'nodes={graph.number_of_nodes()} edges={graph.number_of_edges()}')
render_interactive_graph(graph)
# Out:
# nodes=31 edges=54
